# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
waseemalastal_arabic_english_dataset_path = kagglehub.dataset_download('waseemalastal/arabic-english-dataset')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("waseemalastal/arabic-english-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/waseemalastal/arabic-english-dataset?dataset_version_number=1...
# 100%|██████████| 498k/498k [00:00<00:00, 14.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/waseemalastal/arabic-english-dataset/versions/1

# %%
import csv

with open('ara.txt', 'r') as txt_file, open('output.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    for line in txt_file:
        row = line.strip().split('\t')
        writer.writerow(row)

# %%
import pandas as pd
df=pd.read_csv("output.csv")
df
# Out:
#                                                      Hi.  \
# 0                                                   Run!
# 1                                                  Duck!
# 2                                                  Duck!
# 3                                                  Duck!
# 4                                                  Help!
# ...                                                  ...
# 12517  The mobile phone you have dialed is either swi...
# 12518  If you decide to answer questions now without ...
# 12519  A man touched down on the moon. A wall came do...
# 12520  Ladies and gentlemen, please stand for the nat...
# 12521  There are mothers and fathers who will lie awa...
#
#                                                  مرحبًا.  \
# 0                                                  اركض!
# 1                                             اخفض رأسك!
# 2                                            اخفضي رأسك!
# 3                                         اخفضوا رؤوسكم!
# 4                                                النجدة!
# ...                                                  ...
# 12517  الهاتف المتحرك الذي طلبته مغلق أو خارج نطاق ال...
# 12518  إذا قررت الإجابة عن الأسئلة الآن دون حضور محام...
# 12519  هبط إنسان على سطح القمر، وأنهار حائط في برلين،...
# 12520  سيداتي و سادتي ، رجاءً قفوا للنشيد الوطني للات...
# 12521  وهناك أمهات وآباء سيظلون مستيقظين بعد أن ينام ...
#
#       CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #629296 (Samer)
# 0      CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 1      CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 2      CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 3      CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 4      CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# ...                                                  ...
# 12517  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 12518  CC-BY 2.0 (France) Attribution: tatoeba.org #7...
# 12519  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 12520  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 12521  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
#
# [12522 rows x 3 columns]

# %%
# Load CSV
df = pd.read_csv('output.csv', names=['English', 'Arabic', 'Attribution'], usecols=[0,1])

# %%
df
# Out:
#                                                  English  \
# 0                                                    Hi.
# 1                                                   Run!
# 2                                                  Duck!
# 3                                                  Duck!
# 4                                                  Duck!
# ...                                                  ...
# 12518  The mobile phone you have dialed is either swi...
# 12519  If you decide to answer questions now without ...
# 12520  A man touched down on the moon. A wall came do...
# 12521  Ladies and gentlemen, please stand for the nat...
# 12522  There are mothers and fathers who will lie awa...
#
#                                                   Arabic
# 0                                                مرحبًا.
# 1                                                  اركض!
# 2                                             اخفض رأسك!
# 3                                            اخفضي رأسك!
# 4                                         اخفضوا رؤوسكم!
# ...                                                  ...
# 12518  الهاتف المتحرك الذي طلبته مغلق أو خارج نطاق ال...
# 12519  إذا قررت الإجابة عن الأسئلة الآن دون حضور محام...
# 12520  هبط إنسان على سطح القمر، وأنهار حائط في برلين،...
# 12521  سيداتي و سادتي ، رجاءً قفوا للنشيد الوطني للات...
# 12522  وهناك أمهات وآباء سيظلون مستيقظين بعد أن ينام ...
#
# [12523 rows x 2 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import string
from string import digits
import re
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Input, Dense,Embedding
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import model_from_json
import pickle as pkl
import numpy as np

# %%
# Lowercase
df['English'] = df['English'].str.lower()
df['Arabic'] = df['Arabic'].str.lower()

# Remove punctuation
punct_table = str.maketrans('', '', string.punctuation)
df['English'] = df['English'].apply(lambda x: ' '.join(w.translate(punct_table) for w in x.split()))
df['Arabic'] = df['Arabic'].apply(lambda x: ' '.join(w.translate(punct_table) for w in x.split()))

# Remove digits
digits = str.maketrans('', '', string.digits)
df['English'] = df['English'].apply(lambda x: ' '.join(w.translate(digits) for w in x.split()))
df['Arabic'] = df['Arabic'].apply(lambda x: re.sub(r'[\u0660-\u0669٠-٩]', '', x))

# Strip spaces
df['English'] = df['English'].str.strip()
df['Arabic'] = df['Arabic'].str.strip()

# %%
# Add start and end tokens
df['Arabic'] = df['Arabic'].apply(lambda x: f"start {x} end")

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(df['English'], df['Arabic'], test_size=0.2)

# %%
# Tokenization
input_tokenizer = Tokenizer()
input_tokenizer.fit_on_texts(X_train)
X_train_seq = input_tokenizer.texts_to_sequences(X_train)
X_test_seq = input_tokenizer.texts_to_sequences(X_test)

output_tokenizer = Tokenizer()
output_tokenizer.fit_on_texts(y_train)
y_train_seq = output_tokenizer.texts_to_sequences(y_train)
y_test_seq = output_tokenizer.texts_to_sequences(y_test)

# %%
# Padding
max_input_len = max(len(seq) for seq in X_train_seq)
max_output_len = max(len(seq) for seq in y_train_seq)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_input_len, padding='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=max_input_len, padding='post')
y_train_pad = pad_sequences(y_train_seq, maxlen=max_output_len, padding='post')
y_test_pad = pad_sequences(y_test_seq, maxlen=max_output_len, padding='post')

# %%
# One-hot encode y_train
vocab_target_size = len(output_tokenizer.word_index) + 1
y_train_onehot = tf.keras.utils.to_categorical(y_train_pad, num_classes=vocab_target_size)
y_test_onehot = tf.keras.utils.to_categorical(y_test_pad, num_classes=vocab_target_size)

# %%
# Prepare decoder input (target sequence shifted by 1)
y_train_decoder_input = np.zeros_like(y_train_pad)
y_train_decoder_input[:, 1:] = y_train_pad[:, :-1]

# %%
latent_dim = 50

encoder_inputs = Input(shape=(None,), name="encoder_inputs")
encoder_embedding = Embedding(input_dim=len(input_tokenizer.word_index)+1, output_dim=latent_dim, mask_zero=True)(encoder_inputs)
encoder_lstm, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,), name="decoder_inputs")
decoder_embedding = Embedding(input_dim=vocab_target_size, output_dim=latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm, _, _ = LSTM(latent_dim, return_sequences=True, return_state=True)(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_target_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_lstm)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Prepare decoder input (target sequence shifted by 1)
y_train_decoder_input = np.zeros_like(y_train_pad)
y_train_decoder_input[:, 1:] = y_train_pad[:, :-1]

# %%
# Train model
model.fit(
    [X_train_pad, y_train_decoder_input],
    y_train_onehot,
    batch_size=128,
    epochs=30,
    validation_split=0.2
)

# %%
# Save the entire model (encoder-decoder architecture + weights + optimizer state)
model.save('english_to_arabic_translator.keras')  # You can also use .h5 extension if preferred

# %%
from tensorflow.keras.models import load_model

model = load_model('english_to_arabic_translator.keras')

# %%
latent_dim = 50
encoder_inputs_inf = model.input[0]
encoder_outputs_inf, inf_state_h, inf_state_c = model.layers[4].output
encoder_inf_states = [inf_state_h, inf_state_c]
encoder_model = Model(encoder_inputs_inf, encoder_inf_states)

# %%
encoder_inputs_inf = model.input[0]
encoder_outputs_inf, inf_state_h, inf_state_c = model.layers[4].output
encoder_inf_states = [inf_state_h, inf_state_c]
encoder_model = Model(encoder_inputs_inf, encoder_inf_states)

# %%
decoder_state_h_input = Input(shape=(latent_dim,))
decoder_state_c_input = Input(shape=(latent_dim,))
decoder_state_input = [decoder_state_h_input, decoder_state_c_input]

decoder_input_inf = model.input[1]
decoder_emb_inf = model.layers[3](decoder_input_inf)
decoder_lstm_inf = model.layers[5]
decoder_output_inf, decoder_state_h_inf, decoder_state_c_inf = decoder_lstm_inf(
    decoder_emb_inf, initial_state=decoder_state_input
)

decoder_state_inf = [decoder_state_h_inf, decoder_state_c_inf]
dense_inf = model.layers[6]
decoder_output_final = dense_inf(decoder_output_inf)

decoder_model = Model(
    [decoder_input_inf] + decoder_state_input,
    [decoder_output_final] + decoder_state_inf
)

# %%
reverse_word_map_target = dict(map(reversed, output_tokenizer.word_index.items()))

# %%
def decode_seq(input_seq):
    state_values = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = output_tokenizer.word_index['start']
    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + state_values)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = reverse_word_map_target.get(sampled_token_index, '')

        decoded_sentence += ' ' + sampled_word

        if sampled_word == 'end' or len(decoded_sentence.split()) > 70:
            stop_condition = True

        target_seq[0, 0] = sampled_token_index
        state_values = [h, c]

    return decoded_sentence

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

for i in range(30):
    sentence = X_test[i]
    original_target = y_test[i]
    input_seq = input_tokenizer.texts_to_sequences([sentence])
    pad_seq = pad_sequences(input_seq, maxlen=30, padding='post')
    predicted_target = decode_seq(pad_seq)

    print("Test sentence:", i+1)
    print("Input:", sentence)
    print("Original Translation:", original_target[6:-4])
    print("Predicted Translation:", predicted_target.strip().replace('end', '').strip())
    print("==" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /tmp/ipykernel_100/1082623263.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sentence = X_test[i]
# /tmp/ipykernel_100/1082623263.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   original_target = y_test[i]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 1
# Input: لقد خالفت القوانين
# Original Translation: ccby 20 france attribution tatoebaorg 16216 ck  393953 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 2
# Input: حُلت المشكلة
# Original Translation: ccby 20 france attribution tatoebaorg 2406532 ck  3054777 altusi
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 3
# Input: لهؤلاء الذين يريدون تمزيق العالم إلى أشلاء، أقول أننا سنلحق بكم الهزيمة
# Original Translation: ccby 20 france attribution tatoebaorg 347784 zifre  376819 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 4
# Input: صنعت لي أُمّي دُمْيَة
# Original Translation: ccby 20 france attribution tatoebaorg 320756 cm  11636729 elmassoudi
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Test sentence: 5
# Input: توم له الحق في معرفة الحقيقة
# Original Translation: ccby 20 france attribution tatoebaorg 1025461 ck  6794092 mouna
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 6
# Input: إذا أردت الحصول على دراجة جديدة، من الفضل لك أن تبدأ بتوفير النقود
# Original Translation: ccby 20 france attribution tatoebaorg 269175 ck  523524 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 7
# Input: أعطى بلده حياته
# Original Translation: ccby 20 france attribution tatoebaorg 296421 ck  833353 samer
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Test sentence: 8
# Input: أصبح ابنه عازف بيانو شهير
# Original Translation: ccby 20 france attribution tatoebaorg 287047 ck  1409296 alanood
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Test sentence: 9
# Input: عادةً ما نفطر السابعة و النصف صباحاً
# Original Translation: ccby 20 france attribution tatoebaorg 248282 ck  374776 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Test sentence: 10
# Input: أحضرها لي
# Original Translation: ccby 20 france attribution tatoebaorg 41817 ck  371048 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 11
# Input: القليل يعرف الخطة
# Original Translation: ccby 20 france attribution tatoebaorg 33317 ck  515063 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test sentence: 12
# Input: لقد حدث هذا الحادث بسبب إهماله
# Original Translation: ccby 20 france attribution tatoebaorg 287415 darinmex  5380120 aboubasha
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test sentence: 13
# Input: من الأفضل أن تغادر إن الوقت متأخر
# Original Translation: ccby 20 france attribution tatoebaorg 372035 saeb  372034 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Test sentence: 14
# Input: نتفائل به
# Original Translation: ccby 20 france attribution tatoebaorg 4904901 ck  4947639 damascene
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test sentence: 15
# Input: كان توم دكتور جامعي
# Original Translation: ccby 20 france attribution tatoebaorg 6352546 ck  8677285 ahmedwaleed
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Test sentence: 16
# Input: توم ليس متسامحا مثلي
# Original Translation: ccby 20 france attribution tatoebaorg 3431017 ck  4951863 damascene
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test sentence: 17
# Input: لا، شكراً لك لقد شبعت
# Original Translation: ccby 20 france attribution tatoebaorg 65670 ck  402322 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Test sentence: 18
# Input: استرح
# Original Translation: ccby 20 france attribution tatoebaorg 1722133 shanghainese  371606 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test sentence: 19
# Input: أمي مجنونه
# Original Translation: ccby 20 france attribution tatoebaorg 627252 cm  987287 damascene
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Test sentence: 20
# Input: من أين يأتي الصّبيان؟
# Original Translation: ccby 20 france attribution tatoebaorg 1637230 spamster  7976229 osohombre
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test sentence: 21
# Input: أغرب عن وجهي
# Original Translation: ccby 20 france attribution tatoebaorg 37902 cm  5496726 wildflower81
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test sentence: 22
# Input: جميعنا متأكدون من براءته
# Original Translation: ccby 20 france attribution tatoebaorg 248349 ck  500565 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Test sentence: 23
# Input: ما ثمن هذه القبّعة؟
# Original Translation: ccby 20 france attribution tatoebaorg 57128 ck  372532 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test sentence: 24
# Input: عندي ابنان
# Original Translation: ccby 20 france attribution tatoebaorg 2714934 ck  2715175 damascene
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 25
# Input: من يدرّسك الفرنسية؟
# Original Translation: ccby 20 france attribution tatoebaorg 40482 ck  371656 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test sentence: 26
# Input: يقع بيتي بالقرب من نقطة انتظار الحافلة
# Original Translation: ccby 20 france attribution tatoebaorg 250534 ck  498669 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test sentence: 27
# Input: ما الذي تتحدث عنه؟
# Original Translation: ccby 20 france attribution tatoebaorg 2066 ck  1108673 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Test sentence: 28
# Input: أدين بنجاحي لصديقي
# Original Translation: ccby 20 france attribution tatoebaorg 251285 eldad  377006 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test sentence: 29
# Input: هل آذيتم أنفسكم؟
# Original Translation: ccby 20 france attribution tatoebaorg 7737855 ck  7739603 misterbrown
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test sentence: 30
# Input: أطفئ النور إذا سمحت
# Original Translation: ccby 20 france attribution tatoebaorg 38829 ck  398463 saeb
# Predicted Translation: ccby 20 france attribution tatoebaorg ck saeb saeb
# ====================================================================================================

# %%
# Encoder inference model
encoder_model = Model(encoder_inputs, encoder_states)

# %%
# Decoder inference model
decoder_state_input_h = Input(shape=(latent_dim,), name="decoder_input_h")
decoder_state_input_c = Input(shape=(latent_dim,), name="decoder_input_c")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# Decoder inputs for inference
decoder_inputs_inf = Input(shape=(None,), name="decoder_inputs_infer")
decoder_embedding_inf = Embedding(input_dim=vocab_target_size, output_dim=latent_dim, mask_zero=True)(decoder_inputs_inf)

# LSTM should return sequences and states
decoder_lstm_inf, state_h_inf, state_c_inf = LSTM(latent_dim, return_sequences=True, return_state=True)(
    decoder_embedding_inf, initial_state=decoder_states_inputs)

decoder_outputs_inf = Dense(vocab_target_size, activation='softmax')(decoder_lstm_inf)

# Decoder model for inference
decoder_model = Model(
    [decoder_inputs_inf] + decoder_states_inputs,
    [decoder_outputs_inf, state_h_inf, state_c_inf]
)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence with just the <start> token
    target_seq = np.array([[output_tokenizer.word_index['start']]])

    decoded_sentence = ''

    for _ in range(max_decoder_seq_length):
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = output_tokenizer.index_word.get(sampled_token_index, '')

        if sampled_word == 'end' or sampled_word == '':
            break

        decoded_sentence += ' ' + sampled_word

        # Update target sequence (of length 1)
        target_seq = np.array([[sampled_token_index]])

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# %%
# Example input sentence
test_sentence = "hello how are you"
max_decoder_seq_length = 20

# Preprocess the input sentence
seq = input_tokenizer.texts_to_sequences([test_sentence])
seq = pad_sequences(seq, maxlen=max_input_len, padding='post')

# Translate
translated_text = decode_sequence(seq)
print("Translated:", translated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Translated: 458435 4939823 2111924 9074404 29922 31908 617345 456737 1417785 7737901 6874258 6874258 11712144 6874258 3199838 475750 376287 252384 252384 bravesentry

# %%
# Example: Preprocess new English sentence
input_sentence = "How are you?"
input_seq = input_tokenizer.texts_to_sequences([input_sentence.lower()])
input_seq = pad_sequences(input_seq, maxlen=max_input_len, padding='post')

# %%
# Get encoder's output states
enc_out, state_h, state_c = model.predict(input_seq)

# Prepare decoder input (start token)
target_seq = np.array([[tokenizer_arabic.word_index['start']]])

decoded_sentence = ''
stop_condition = False

while not stop_condition:
    output_tokens, h, c = model.predict([target_seq, enc_out, state_h, state_c])

    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_word = tokenizer_arabic.index_word.get(sampled_token_index, '')

    if sampled_word == 'end' or len(decoded_sentence.split()) > max_target_length:
        stop_condition = True
    else:
        decoded_sentence += ' ' + sampled_word

    # Update target sequence and states
    target_seq = np.array([[sampled_token_index]])
    state_h, state_c = h, c

print("Translated:", decoded_sentence.strip())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_100/503257391.py in <cell line: 0>()
#       1 # Get encoder's output states
# ----> 2 enc_out, state_h, state_c = model.predict(input_seq)
#       3
#       4 # Prepare decoder input (start token)
#       5 target_seq = np.array([[tokenizer_arabic.word_index['start']]])
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     158     inputs = tree.flatten(inputs)
#     159     if len(inputs) != len(input_spec):
# --> 160         raise ValueError(
#     161             f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#     162             f" but it received {len(inputs)} input tensors. "
#
# ValueError: Layer "functional" expects 2 input(s), but it received 1 input tensors. Inputs received: [<tf.Tensor 'data:0' shape=(1, 36) dtype=int32>]
